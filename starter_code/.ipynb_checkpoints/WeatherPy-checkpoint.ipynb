# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['puerto ayora',
#  'bredasdorp',
#  'te anau',
#  'alugan',
#  'qaanaaq',
#  'lagoa',
#  'thompson',
#  'mataura',
#  'jamestown',
#  'albany',
#  'souillac',
#  'hermanus',
#  'severo-kurilsk',
#  'arraial do cabo',
#  'rikitea',
#  'castro',
#  'santa maria',
#  'punta arenas',
#  'vaini',
#  'skjervoy',
#  'nouakchott',
#  'dikson',
#  'atuona',
#  'tsihombe',
#  'geraldton',
#  'barrow',
#  'saint-philippe',
#  'marcona',
#  'ituni',
#  'palabuhanratu',
#  'dunedin',
#  'faanui',
#  'bluff',
#  'amderma',
#  'upernavik',
#  'luderitz',
#  'beloha',
#  'karamea',
#  'busselton',
#  'cape town',
#  'georgetown',
#  'hobart',
#  'itarema',
#  'saint george',
#  'sambava',
#  'udankudi',
#  'nikolskoye',
#  'codrington',
#  'mitu',
#  'nelson bay',
#  'florianopolis',
#  'airai',
#  'moyale',
#  'ushuaia',
#  'makat',
#  'san patricio',
#  'svetlyy',
#  'kapaa',
#  'belushya guba',
#  'leningradskiy',
#  'richards bay',
#  'chuy',
#  'san isidro',
#  'katsuura',
#  'lata',
#  'nizhneyansk',
#  'havoysund',
#  'half moon bay',
#  'barentsburg',
#  'new norfolk',
#  'avera',
#  'thunder bay',
#  'bafq',
#  'aporawan',
#  'bethel',
#  'hithadhoo',
#  'muisne',
#  'touros',
#  'voznesenye',
#  'volno-nadezhdinskoye',
#  'avarua',
#  'peniche',
#  'ponta do sol',
#  'provideniya',
#  'clyde river',
#  'rongcheng',
#  'qaqortoq',
#  'sobolevo',
#  'hihifo',
#  'enshi',
#  'dalmeny',
#  'lebu',
#  'port alfred',
#  'vostok',
#  'bilma',
#  'east london',
#  'hasaki',
#  'carnarvon',
#  'hofn',
#  'norman wells',
#  'hilo',
#  'srandakan',
#  'khandyga',
#  'khonuu',
#  'martapura',
#  'severobaykalsk',
#  'sabla',
#  'sitka',
#  'cagayan de tawi-tawi',
#  'pong',
#  'greenville',
#  'meulaboh',
#  'khatanga',
#  'kahului',
#  'tuktoyaktuk',
#  'karkaralinsk',
#  'cabo san lucas',
#  'mar del plata',
#  'biltine',
#  'saskylakh',
#  'port victoria',
#  'safaga',
#  'gaya',
#  'tautira',
#  'ust-kamchatsk',
#  'praia',
#  'shitanjing',
#  'tadine',
#  'lincoln',
#  'illoqqortoormiut',
#  'ancud',
#  'butaritari',
#  'achacachi',
#  'defiance',
#  'salalah',
#  'vestmannaeyjar',
#  'taolanaro',
#  'jever',
#  'warqla',
#  'tiksi',
#  'mount isa',
#  'lucapa',
#  'kieta',
#  'changji',
#  'yulara',
#  'tanshui',
#  'kalianget',
#  'maningrida',
#  'husavik',
#  'hakvik',
#  'camacha',
#  'kuah',
#  'talcahuano',
#  'necochea',
#  'los llanos de aridane',
#  'gamba',
#  'madimba',
#  'goundam',
#  'yellowknife',
#  'port blair',
#  'moose factory',
#  'acari',
#  'channel-port aux basques',
#  'olinda',
#  'laguna',
#  'isoka',
#  'hit',
#  'kodiak',
#  'victoria',
#  'kaitangata',
#  'ngukurr',
#  'mahebourg',
#  'tukrah',
#  'jau',
#  'digoin',
#  'korla',
#  'benghazi',
#  'yuncheng',
#  'yar-sale',
#  'tessalit',
#  'chemin grenier',
#  'bargal',
#  'umzimvubu',
#  'bambous virieux',
#  'puerto escondido',
#  'aklavik',
#  'bulacan',
#  'tasiilaq',
#  'mount gambier',
#  'pacific grove',
#  'cherskiy',
#  'tromso',
#  'inhambane',
#  'kismayo',
#  'olecko',
#  'saleaula',
#  'saint-denis',
#  'kruisfontein',
#  'srednekolymsk',
#  'jalu',
#  'kungurtug',
#  'bengkulu',
#  'seddon',
#  'ilinsko-podomskoye',
#  'bako',
#  'port augusta',
#  'along',
#  'mackay',
#  'salina',
#  'barbar',
#  'lorengau',
#  'torbay',
#  'sao felix do xingu',
#  'pangkalanbuun',
#  'gudiyattam',
#  'manicore',
#  'talnakh',
#  'kavieng',
#  'longyearbyen',
#  'pimentel',
#  'pavlodar',
#  'carmarthen',
#  'cartagena',
#  'dalvik',
#  'ben tre',
#  'westport',
#  'aitape',
#  'tabas',
#  'hualmay',
#  'state college',
#  'summerville',
#  'cascais',
#  'sistranda',
#  'quatre cocos',
#  'samarai',
#  'labuhan',
#  'we',
#  'muros',
#  'riyadh',
#  'mendi',
#  'giresun',
#  'ifakara',
#  'dwarka',
#  'carutapera',
#  'qarqin',
#  'odweyne',
#  'vila franca do campo',
#  'paamiut',
#  'linguere',
#  'ilulissat',
#  'luanda',
#  'astana',
#  'storforshei',
#  'cidreira',
#  'panama city',
#  'kapuskasing',
#  'tarko-sale',
#  'isangel',
#  'muramatsu',
#  'shar',
#  'komsomolskiy',
#  'cotoca',
#  'port elizabeth',
#  'porto seguro',
#  'sibolga',
#  'divo',
#  'hamilton',
#  'nanortalik',
#  'attawapiskat',
#  'samalaeulu',
#  'guerrero negro',
#  'kitob',
#  'pevek',
#  'pisco',
#  'jaisalmer',
#  'nosy varika',
#  'port macquarie',
#  'esik',
#  'chokurdakh',
#  'jiutai',
#  'kondinskoye',
#  'mys shmidta',
#  'pocone',
#  'vaitupu',
#  'egvekinot',
#  'quelimane',
#  'nizwa',
#  'wajima',
#  'monster',
#  'audru',
#  'batagay',
#  'mehran',
#  'gisborne',
#  'carlagan',
#  'hobyo',
#  'luganville',
#  'umm lajj',
#  'emerald',
#  'sorong',
#  'snezhnogorsk',
#  'stavern',
#  'port keats',
#  'ketchikan',
#  'kilembe',
#  'fukue',
#  'klaksvik',
#  'colares',
#  'esso',
#  'adre',
#  'olafsvik',
#  'ruatoria',
#  'joshimath',
#  'plast',
#  'ust-tsilma',
#  'esperance',
#  'mendahara',
#  'padang',
#  'chicama',
#  'leshukonskoye',
#  'dolores',
#  'roma',
#  'kang',
#  'maltahohe',
#  'cody',
#  'tokur',
#  'senhor do bonfim',
#  'arlit',
#  'coihaique',
#  'berlevag',
#  'nishihara',
#  'sardulgarh',
#  'strathmore',
#  'ondorhaan',
#  'tiarei',
#  'manado',
#  'herat',
#  'pemagatsel',
#  'sisimiut',
#  'bur gabo',
#  'vanimo',
#  'huarmey',
#  'palembang',
#  'xuddur',
#  'havelock',
#  'abu dhabi',
#  'zyryanka',
#  'niksar',
#  'namatanai',
#  'oistins',
#  'sernovodsk',
#  'petropavlovsk-kamchatskiy',
#  'dudinka',
#  'palmer',
#  'biloela',
#  'salamiyah',
#  'berezovyy',
#  'koyelga',
#  'morgan city',
#  'orsk',
#  'baldone',
#  'ribeira grande',
#  'bilibino',
#  'griffith',
#  'tchibanga',
#  'fortuna',
#  'jasper',
#  'aljezur',
#  'tuggurt',
#  'severo-yeniseyskiy',
#  'tabialan',
#  'comodoro rivadavia',
#  'sentyabrskiy',
#  'shangrao',
#  'soskovo',
#  'san jose',
#  'stokmarknes',
#  'camana',
#  'college',
#  'rocha',
#  'boyolangu',
#  'kurilsk',
#  'ogaminana',
#  'ust-kuyga',
#  'grenville',
#  'chifeng',
#  'marawi',
#  'yasnogorsk',
#  'selikhino',
#  'wiesmoor',
#  'mirabad',
#  'mamlyutka',
#  'havre-saint-pierre',
#  'semey',
#  'monrovia',
#  'ocos',
#  'marapanim',
#  'labytnangi',
#  'kingaroy',
#  'erenhot',
#  'narsaq',
#  'stromness',
#  'ocean city',
#  'ibanda',
#  'taltal',
#  'mindelo',
#  'khor',
#  'bonthe',
#  'beringovskiy',
#  'wadi musa',
#  'margate',
#  'tenenkou',
#  'cabrobo',
#  'morondava',
#  'ekhabi',
#  'svetlogorsk',
#  'caraballeda',
#  'bermejo',
#  'hailar',
#  'omboue',
#  'ixtapa',
#  'caravelas',
#  'sorland',
#  'sept-iles',
#  'saint anthony',
#  'anshun',
#  'lompoc',
#  'verkhnevilyuysk',
#  'libenge',
#  'de-kastri',
#  'viseu',
#  'uk',
#  'jilib',
#  'seoul',
#  'grand gaube',
#  'lakes entrance',
#  'vardo',
#  'mao',
#  'flinders',
#  'barinas',
#  'constitucion',
#  'godeanu',
#  'nogliki',
#  'isiro',
#  'yarada',
#  'bay roberts',
#  'dunmore east',
#  'san buenaventura',
#  'nemuro',
#  'taoudenni',
#  'dujuma',
#  'turayf',
#  'kargasok',
#  'faya',
#  'carnot',
#  'honiara',
#  'isla vista',
#  'lashio',
#  'abu kamal',
#  'tazmalt',
#  'inuvik',
#  'saldanha',
#  'kamenskoye',
#  'moron',
#  'laredo',
#  'maryville',
#  'mwinilunga',
#  'katangli',
#  'abu samrah',
#  'leh',
#  'la ronge',
#  'bereda',
#  'canto do buriti',
#  'bagdarin',
#  'samusu',
#  'le vauclin',
#  'dawson creek',
#  'anadyr',
#  'lakki marwat',
#  'san quintin',
#  'maldonado',
#  'port moresby',
#  'tomatlan',
#  'tura',
#  'ustye',
#  'bowen',
#  'harper',
#  'tateyama',
#  'teya',
#  'alofi',
#  'nome',
#  'kerema',
#  'acajutla',
#  'calvinia',
#  'abong mbang',
#  'teocaltiche',
#  'hambantota',
#  'ulaangom',
#  'acarau',
#  'kavaratti',
#  'galle',
#  'shingu',
#  'rawson',
#  'realeza',
#  'saint-augustin',
#  'summerside',
#  'chumikan',
#  'tra vinh',
#  'bambanglipuro',
#  'galesong',
#  'maceio',
#  'nkawkaw',
#  'katherine',
#  'burgersdorp',
#  'port hardy',
#  'maymyo',
#  'susehri',
#  'kegayli',
#  'barabinsk',
#  'salaga',
#  'axim',
#  'hamada',
#  'crab hill',
#  'gat',
#  'sirur',
#  'phalaborwa',
#  'pahrump',
#  'hirara',
#  'la sarre',
#  'vao',
#  'cap malheureux',
#  'stornoway',
#  'anchorage',
#  'pandan',
#  'pangnirtung',
#  'belyy yar',
#  'maputo',
#  'fukuma',
#  'poronaysk',
#  'sarankhola',
#  'uruzgan',
#  'krasnoselkup',
#  'rapid valley',
#  'ballina',
#  'kerman',
#  'trat',
#  'ewa beach',
#  'mabaruma',
#  'wakema',
#  'tabiauea',
#  'sandakan',
#  'demirci',
#  'zambezi',
#  'calabozo',
#  'wanning',
#  'mayumba',
#  'acuitzio',
#  'katobu',
#  'cockburn town',
#  'tarudant',
#  'salyan',
#  'ostrovnoy',
#  'araouane',
#  'bose',
#  'cheshunt',
#  'bac lieu',
#  'grahamstown',
#  'nabire',
#  'ambon',
#  'broken hill',
#  'udachnyy',
#  'noumea',
#  'verkhnyaya inta',
#  'tuatapere',
#  'madaoua',
#  'virginia beach',
#  'bonavista',
#  'caldwell',
#  'luancheng',
#  'caronport',
#  'bokovskaya',
#  'uhryniv',
#  'fort nelson',
#  'general roca',
#  'tuensang',
#  'kyzyl-mazhalyk',
#  'mayo',
#  'ilo',
#  'mugur-aksy',
#  'flin flon',
#  'rantauprapat',
#  'save',
#  'sabang',
#  'pasaje',
#  'wiang sa',
#  'champerico',
#  'belaya gora',
#  'bayan',
#  'nadvoitsy',
#  'yumen',
#  'nurota',
#  'qasigiannguit',
#  'manaus',
#  'sao joao da barra',
#  'saveh',
#  'saint-louis',
#  'alyangula',
#  'louisbourg',
#  'batemans bay',
#  'deyskoye',
#  'naze',
#  'santo antonio do ica',
#  'orshanka',
#  'guanare',
#  'goderich',
#  'port lincoln',
#  'chegdomyn',
#  'tak bai',
#  'vila velha',
#  'northam',
#  'kirakira']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_check = []
record_number = 0
city_id = []
city_name = []

weather_api_key = "ea45174aae3e4fc5de1af5d14f74cd81"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
print("Beginning Data Retrieval")
print("------------------------------")
for city in cities:
    city_url = url + "ea45174aae3e4fc5de1af5d14f74cd81&q=" + city
    response_raw = requests.get(city_url)
#     if response_raw.status_code == 200:
    try:
        response = response_raw.json()
        record_number = record_number + 1
        weather_check.append(response['weather'][0]['main'])
        city_id.append(response['id'])
        city_name.append(response['name'])
        weather_dict = {
            "City": city_name,
            "City ID": city_id,
            "Weather": weather_check
        }
        print(f"Processing record {record_number} | {city}")
    except: 
        print("City not found. skipping...")
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing record 1 | puerto ayora
# Processing record 2 | bredasdorp
# Processing record 3 | te anau
# Processing record 4 | alugan
# Processing record 5 | qaanaaq
# Processing record 6 | lagoa
# Processing record 7 | thompson
# Processing record 8 | mataura
# Processing record 9 | jamestown
# Processing record 10 | albany
# Processing record 11 | souillac
# Processing record 12 | hermanus
# Processing record 13 | severo-kurilsk
# Processing record 14 | arraial do cabo
# Processing record 15 | rikitea
# Processing record 16 | castro
# Processing record 17 | santa maria
# Processing record 18 | punta arenas
# Processing record 19 | vaini
# Processing record 20 | skjervoy
# Processing record 21 | nouakchott
# Processing record 22 | dikson
# Processing record 23 | atuona
# City not found. skipping...
# Processing record 25 | geraldton
# Processing record 26 | barrow
# Processing record 27 | saint-philippe
# City not found. skipping...
# City not found. skipping...
# City not found. skipping...
# Processing record 31 | dunedin
# Processing record 32 | faanui
# Processing record 33 | bluff
# City not found. skipping...
# Processing record 35 | upernavik
# Processing record 36 | luderitz
# Processing record 37 | beloha
# City not found. skipping...
# Processing record 39 | busselton
# Processing record 40 | cape town
# Processing record 41 | georgetown
# Processing record 42 | hobart
# Processing record 43 | itarema
# Processing record 44 | saint george
# Processing record 45 | sambava
# Processing record 46 | udankudi
# Processing record 47 | nikolskoye
# Processing record 48 | codrington
# Processing record 49 | mitu
# Processing record 50 | nelson bay
# Processing record 51 | florianopolis
# Processing record 52 | airai
# Processing record 53 | moyale
# Processing record 54 | ushuaia
# Processing record 55 | makat
# Processing record 56 | san patricio
# Processing record 57 | svetlyy
# Processing record 58 | kapaa
# City not found. skipping...
# Processing record 60 | leningradskiy
# Processing record 61 | richards bay
# Processing record 62 | chuy
# Processing record 63 | san isidro
# Processing record 64 | katsuura
# Processing record 65 | lata
# City not found. skipping...
# Processing record 67 | havoysund
# Processing record 68 | half moon bay
# City not found. skipping...
# Processing record 70 | new norfolk
# Processing record 71 | avera
# Processing record 72 | thunder bay
# Processing record 73 | bafq
# City not found. skipping...
# Processing record 75 | bethel
# Processing record 76 | hithadhoo
# Processing record 77 | muisne
# Processing record 78 | touros
# Processing record 79 | voznesenye
# Processing record 80 | volno-nadezhdinskoye
# Processing record 81 | avarua
# Processing record 82 | peniche
# Processing record 83 | ponta do sol
# Processing record 84 | provideniya
# Processing record 85 | clyde river
# Processing record 86 | rongcheng
# Processing record 87 | qaqortoq
# Processing record 88 | sobolevo
# City not found. skipping...
# Processing record 90 | enshi
# Processing record 91 | dalmeny
# Processing record 92 | lebu
# Processing record 93 | port alfred
# Processing record 94 | vostok
# Processing record 95 | bilma
# Processing record 96 | east london
# Processing record 97 | hasaki
# Processing record 98 | carnarvon
# Processing record 99 | hofn
# Processing record 100 | norman wells
# Processing record 101 | hilo
# Processing record 102 | srandakan
# Processing record 103 | khandyga
# City not found. skipping...
# Processing record 105 | martapura
# Processing record 106 | severobaykalsk
# Processing record 107 | sabla
# Processing record 108 | sitka
# City not found. skipping...
# Processing record 110 | pong
# Processing record 111 | greenville
# Processing record 112 | meulaboh
# Processing record 113 | khatanga
# Processing record 114 | kahului
# Processing record 115 | tuktoyaktuk
# City not found. skipping...
# Processing record 117 | cabo san lucas
# Processing record 118 | mar del plata
# Processing record 119 | biltine
# Processing record 120 | saskylakh
# Processing record 121 | port victoria
# Processing record 122 | safaga
# Processing record 123 | gaya
# Processing record 124 | tautira
# City not found. skipping...
# Processing record 126 | praia
# Processing record 127 | shitanjing
# Processing record 128 | tadine
# Processing record 129 | lincoln
# City not found. skipping...
# Processing record 131 | ancud
# Processing record 132 | butaritari
# Processing record 133 | achacachi
# Processing record 134 | defiance
# Processing record 135 | salalah
# Processing record 136 | vestmannaeyjar
# City not found. skipping...
# Processing record 138 | jever
# City not found. skipping...
# Processing record 140 | tiksi
# Processing record 141 | mount isa
# Processing record 142 | lucapa
# Processing record 143 | kieta
# Processing record 144 | changji
# Processing record 145 | yulara
# City not found. skipping...
# Processing record 147 | kalianget
# Processing record 148 | maningrida
# Processing record 149 | husavik
# City not found. skipping...
# Processing record 151 | camacha
# Processing record 152 | kuah
# Processing record 153 | talcahuano
# Processing record 154 | necochea
# Processing record 155 | los llanos de aridane
# Processing record 156 | gamba
# Processing record 157 | madimba
# Processing record 158 | goundam
# Processing record 159 | yellowknife
# Processing record 160 | port blair
# Processing record 161 | moose factory
# Processing record 162 | acari
# Processing record 163 | channel-port aux basques
# Processing record 164 | olinda
# Processing record 165 | laguna
# Processing record 166 | isoka
# Processing record 167 | hit
# Processing record 168 | kodiak
# Processing record 169 | victoria
# Processing record 170 | kaitangata
# City not found. skipping...
# Processing record 172 | mahebourg
# Processing record 173 | tukrah
# Processing record 174 | jau
# Processing record 175 | digoin
# Processing record 176 | korla
# Processing record 177 | benghazi
# Processing record 178 | yuncheng
# Processing record 179 | yar-sale
# Processing record 180 | tessalit
# Processing record 181 | chemin grenier
# City not found. skipping...
# City not found. skipping...
# Processing record 184 | bambous virieux
# Processing record 185 | puerto escondido
# Processing record 186 | aklavik
# Processing record 187 | bulacan
# Processing record 188 | tasiilaq
# Processing record 189 | mount gambier
# Processing record 190 | pacific grove
# Processing record 191 | cherskiy
# Processing record 192 | tromso
# Processing record 193 | inhambane
# Processing record 194 | kismayo
# Processing record 195 | olecko
# City not found. skipping...
# Processing record 197 | saint-denis
# Processing record 198 | kruisfontein
# Processing record 199 | srednekolymsk
# Processing record 200 | jalu
# Processing record 201 | kungurtug
# Processing record 202 | bengkulu
# Processing record 203 | seddon
# City not found. skipping...
# Processing record 205 | bako
# Processing record 206 | port augusta
# Processing record 207 | along
# Processing record 208 | mackay
# Processing record 209 | salina
# City not found. skipping...
# Processing record 211 | lorengau
# Processing record 212 | torbay
# Processing record 213 | sao felix do xingu
# Processing record 214 | pangkalanbuun
# City not found. skipping...
# Processing record 216 | manicore
# Processing record 217 | talnakh
# Processing record 218 | kavieng
# Processing record 219 | longyearbyen
# Processing record 220 | pimentel
# Processing record 221 | pavlodar
# Processing record 222 | carmarthen
# Processing record 223 | cartagena
# Processing record 224 | dalvik
# Processing record 225 | ben tre
# Processing record 226 | westport
# Processing record 227 | aitape
# Processing record 228 | tabas
# Processing record 229 | hualmay
# Processing record 230 | state college
# Processing record 231 | summerville
# Processing record 232 | cascais
# Processing record 233 | sistranda
# Processing record 234 | quatre cocos
# Processing record 235 | samarai
# Processing record 236 | labuhan
# City not found. skipping...
# Processing record 238 | muros
# Processing record 239 | riyadh
# Processing record 240 | mendi
# Processing record 241 | giresun
# Processing record 242 | ifakara
# Processing record 243 | dwarka
# Processing record 244 | carutapera
# Processing record 245 | qarqin
# Processing record 246 | odweyne
# Processing record 247 | vila franca do campo
# Processing record 248 | paamiut
# Processing record 249 | linguere
# Processing record 250 | ilulissat
# Processing record 251 | luanda
# Processing record 252 | astana
# Processing record 253 | storforshei
# Processing record 254 | cidreira
# Processing record 255 | panama city
# Processing record 256 | kapuskasing
# Processing record 257 | tarko-sale
# Processing record 258 | isangel
# Processing record 259 | muramatsu
# Processing record 260 | shar
# Processing record 261 | komsomolskiy
# Processing record 262 | cotoca
# Processing record 263 | port elizabeth
# Processing record 264 | porto seguro
# Processing record 265 | sibolga
# Processing record 266 | divo
# Processing record 267 | hamilton
# Processing record 268 | nanortalik
# City not found. skipping...
# City not found. skipping...
# Processing record 271 | guerrero negro
# Processing record 272 | kitob
# Processing record 273 | pevek
# Processing record 274 | pisco
# Processing record 275 | jaisalmer
# Processing record 276 | nosy varika
# Processing record 277 | port macquarie
# Processing record 278 | esik
# Processing record 279 | chokurdakh
# Processing record 280 | jiutai
# Processing record 281 | kondinskoye
# City not found. skipping...
# Processing record 283 | pocone
# City not found. skipping...
# Processing record 285 | egvekinot
# Processing record 286 | quelimane
# Processing record 287 | nizwa
# Processing record 288 | wajima
# Processing record 289 | monster
# Processing record 290 | audru
# Processing record 291 | batagay
# Processing record 292 | mehran
# Processing record 293 | gisborne
# Processing record 294 | carlagan
# Processing record 295 | hobyo
# Processing record 296 | luganville
# Processing record 297 | umm lajj
# Processing record 298 | emerald
# Processing record 299 | sorong
# Processing record 300 | snezhnogorsk
# Processing record 301 | stavern
# Processing record 302 | port keats
# Processing record 303 | ketchikan
# Processing record 304 | kilembe
# Processing record 305 | fukue
# Processing record 306 | klaksvik
# Processing record 307 | colares
# Processing record 308 | esso
# Processing record 309 | adre
# Processing record 310 | olafsvik
# City not found. skipping...
# Processing record 312 | joshimath
# Processing record 313 | plast
# Processing record 314 | ust-tsilma
# Processing record 315 | esperance
# City not found. skipping...
# Processing record 317 | padang
# Processing record 318 | chicama
# Processing record 319 | leshukonskoye
# Processing record 320 | dolores
# Processing record 321 | roma
# Processing record 322 | kang
# Processing record 323 | maltahohe
# Processing record 324 | cody
# Processing record 325 | tokur
# Processing record 326 | senhor do bonfim
# Processing record 327 | arlit
# Processing record 328 | coihaique
# Processing record 329 | berlevag
# Processing record 330 | nishihara
# Processing record 331 | sardulgarh
# Processing record 332 | strathmore
# City not found. skipping...
# Processing record 334 | tiarei
# Processing record 335 | manado
# Processing record 336 | herat
# Processing record 337 | pemagatsel
# Processing record 338 | sisimiut
# City not found. skipping...
# Processing record 340 | vanimo
# Processing record 341 | huarmey
# Processing record 342 | palembang
# Processing record 343 | xuddur
# Processing record 344 | havelock
# Processing record 345 | abu dhabi
# Processing record 346 | zyryanka
# Processing record 347 | niksar
# Processing record 348 | namatanai
# Processing record 349 | oistins
# Processing record 350 | sernovodsk
# Processing record 351 | petropavlovsk-kamchatskiy
# Processing record 352 | dudinka
# Processing record 353 | palmer
# Processing record 354 | biloela
# Processing record 355 | salamiyah
# Processing record 356 | berezovyy
# Processing record 357 | koyelga
# Processing record 358 | morgan city
# Processing record 359 | orsk
# Processing record 360 | baldone
# Processing record 361 | ribeira grande
# Processing record 362 | bilibino
# Processing record 363 | griffith
# Processing record 364 | tchibanga
# Processing record 365 | fortuna
# Processing record 366 | jasper
# Processing record 367 | aljezur
# City not found. skipping...
# Processing record 369 | severo-yeniseyskiy
# City not found. skipping...
# Processing record 371 | comodoro rivadavia
# City not found. skipping...
# Processing record 373 | shangrao
# Processing record 374 | soskovo
# Processing record 375 | san jose
# Processing record 376 | stokmarknes
# Processing record 377 | camana
# Processing record 378 | college
# Processing record 379 | rocha
# Processing record 380 | boyolangu
# Processing record 381 | kurilsk
# Processing record 382 | ogaminana
# Processing record 383 | ust-kuyga
# Processing record 384 | grenville
# Processing record 385 | chifeng
# Processing record 386 | marawi
# Processing record 387 | yasnogorsk
# Processing record 388 | selikhino
# Processing record 389 | wiesmoor
# Processing record 390 | mirabad
# Processing record 391 | mamlyutka
# Processing record 392 | havre-saint-pierre
# Processing record 393 | semey
# Processing record 394 | monrovia
# Processing record 395 | ocos
# Processing record 396 | marapanim
# Processing record 397 | labytnangi
# Processing record 398 | kingaroy
# Processing record 399 | erenhot
# Processing record 400 | narsaq
# Processing record 401 | stromness
# Processing record 402 | ocean city
# Processing record 403 | ibanda
# Processing record 404 | taltal
# Processing record 405 | mindelo
# Processing record 406 | khor
# Processing record 407 | bonthe
# Processing record 408 | beringovskiy
# Processing record 409 | wadi musa
# Processing record 410 | margate
# Processing record 411 | tenenkou
# Processing record 412 | cabrobo
# Processing record 413 | morondava
# Processing record 414 | ekhabi
# Processing record 415 | svetlogorsk
# Processing record 416 | caraballeda
# Processing record 417 | bermejo
# Processing record 418 | hailar
# Processing record 419 | omboue
# Processing record 420 | ixtapa
# Processing record 421 | caravelas
# Processing record 422 | sorland
# Processing record 423 | sept-iles
# Processing record 424 | saint anthony
# Processing record 425 | anshun
# Processing record 426 | lompoc
# Processing record 427 | verkhnevilyuysk
# Processing record 428 | libenge
# Processing record 429 | de-kastri
# Processing record 430 | viseu
# City not found. skipping...
# Processing record 432 | jilib
# Processing record 433 | seoul
# Processing record 434 | grand gaube
# Processing record 435 | lakes entrance
# Processing record 436 | vardo
# Processing record 437 | mao
# Processing record 438 | flinders
# Processing record 439 | barinas
# Processing record 440 | constitucion
# Processing record 441 | godeanu
# Processing record 442 | nogliki
# Processing record 443 | isiro
# Processing record 444 | yarada
# Processing record 445 | bay roberts
# Processing record 446 | dunmore east
# Processing record 447 | san buenaventura
# Processing record 448 | nemuro
# Processing record 449 | taoudenni
# City not found. skipping...
# Processing record 451 | turayf
# Processing record 452 | kargasok
# Processing record 453 | faya
# Processing record 454 | carnot
# Processing record 455 | honiara
# Processing record 456 | isla vista
# Processing record 457 | lashio
# Processing record 458 | abu kamal
# Processing record 459 | tazmalt
# Processing record 460 | inuvik
# Processing record 461 | saldanha
# City not found. skipping...
# Processing record 463 | moron
# Processing record 464 | laredo
# Processing record 465 | maryville
# Processing record 466 | mwinilunga
# Processing record 467 | katangli
# Processing record 468 | abu samrah
# Processing record 469 | leh
# Processing record 470 | la ronge
# Processing record 471 | bereda
# Processing record 472 | canto do buriti
# Processing record 473 | bagdarin
# City not found. skipping...
# Processing record 475 | le vauclin
# Processing record 476 | dawson creek
# Processing record 477 | anadyr
# Processing record 478 | lakki marwat
# Processing record 479 | san quintin
# Processing record 480 | maldonado
# Processing record 481 | port moresby
# Processing record 482 | tomatlan
# Processing record 483 | tura
# Processing record 484 | ustye
# Processing record 485 | bowen
# Processing record 486 | harper
# Processing record 487 | tateyama
# Processing record 488 | teya
# Processing record 489 | alofi
# Processing record 490 | nome
# Processing record 491 | kerema
# Processing record 492 | acajutla
# Processing record 493 | calvinia
# Processing record 494 | abong mbang
# Processing record 495 | teocaltiche
# Processing record 496 | hambantota
# Processing record 497 | ulaangom
# Processing record 498 | acarau
# Processing record 499 | kavaratti
# Processing record 500 | galle
# Processing record 501 | shingu
# Processing record 502 | rawson
# Processing record 503 | realeza
# Processing record 504 | saint-augustin
# Processing record 505 | summerside
# Processing record 506 | chumikan
# Processing record 507 | tra vinh
# Processing record 508 | bambanglipuro
# Processing record 509 | galesong
# Processing record 510 | maceio
# Processing record 511 | nkawkaw
# Processing record 512 | katherine
# Processing record 513 | burgersdorp
# Processing record 514 | port hardy
# Processing record 515 | maymyo
# Processing record 516 | susehri
# City not found. skipping...
# Processing record 518 | barabinsk
# Processing record 519 | salaga
# Processing record 520 | axim
# Processing record 521 | hamada
# City not found. skipping...
# Processing record 523 | gat
# Processing record 524 | sirur
# Processing record 525 | phalaborwa
# Processing record 526 | pahrump
# Processing record 527 | hirara
# Processing record 528 | la sarre
# Processing record 529 | vao
# Processing record 530 | cap malheureux
# Processing record 531 | stornoway
# Processing record 532 | anchorage
# Processing record 533 | pandan
# Processing record 534 | pangnirtung
# Processing record 535 | belyy yar
# Processing record 536 | maputo
# Processing record 537 | fukuma
# Processing record 538 | poronaysk
# Processing record 539 | sarankhola
# Processing record 540 | uruzgan
# Processing record 541 | krasnoselkup
# Processing record 542 | rapid valley
# Processing record 543 | ballina
# Processing record 544 | kerman
# Processing record 545 | trat
# Processing record 546 | ewa beach
# Processing record 547 | mabaruma
# Processing record 548 | wakema
# City not found. skipping...
# Processing record 550 | sandakan
# Processing record 551 | demirci
# Processing record 552 | zambezi
# Processing record 553 | calabozo
# Processing record 554 | wanning
# Processing record 555 | mayumba
# Processing record 556 | acuitzio
# Processing record 557 | katobu
# Processing record 558 | cockburn town
# City not found. skipping...
# Processing record 560 | salyan
# Processing record 561 | ostrovnoy
# Processing record 562 | araouane
# Processing record 563 | bose
# Processing record 564 | cheshunt
# Processing record 565 | bac lieu
# Processing record 566 | grahamstown
# Processing record 567 | nabire
# Processing record 568 | ambon
# Processing record 569 | broken hill
# Processing record 570 | udachnyy
# Processing record 571 | noumea
# Processing record 572 | verkhnyaya inta
# Processing record 573 | tuatapere
# Processing record 574 | madaoua
# Processing record 575 | virginia beach
# Processing record 576 | bonavista
# Processing record 577 | caldwell
# Processing record 578 | luancheng
# Processing record 579 | caronport
# Processing record 580 | bokovskaya
# Processing record 581 | uhryniv
# Processing record 582 | fort nelson
# Processing record 583 | general roca
# Processing record 584 | tuensang
# Processing record 585 | kyzyl-mazhalyk
# Processing record 586 | mayo
# Processing record 587 | ilo
# Processing record 588 | mugur-aksy
# Processing record 589 | flin flon
# Processing record 590 | rantauprapat
# Processing record 591 | save
# Processing record 592 | sabang
# Processing record 593 | pasaje
# Processing record 594 | wiang sa
# Processing record 595 | champerico
# Processing record 596 | belaya gora
# Processing record 597 | bayan
# Processing record 598 | nadvoitsy
# Processing record 599 | yumen
# Processing record 600 | nurota
# Processing record 601 | qasigiannguit
# Processing record 602 | manaus
# Processing record 603 | sao joao da barra
# Processing record 604 | saveh
# Processing record 605 | saint-louis
# Processing record 606 | alyangula
# City not found. skipping...
# Processing record 608 | batemans bay
# Processing record 609 | deyskoye
# Processing record 610 | naze
# Processing record 611 | santo antonio do ica
# Processing record 612 | orshanka
# Processing record 613 | guanare
# Processing record 614 | goderich
# Processing record 615 | port lincoln
# Processing record 616 | chegdomyn
# Processing record 617 | tak bai
# Processing record 618 | vila velha
# Processing record 619 | northam
# Processing record 620 | kirakira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_id = 1
city_id_list=[]
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

for city in cities:
    city_url = url + "ea45174aae3e4fc5de1af5d14f74cd81&q=" + city
    response_raw = requests.get(city_url)
    if response_raw.status_code == 200:
        city_id_list.append(city_id)
        response = response_raw.json()
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt']) 
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        city_id = city_id + 1

cities_dict = {
    "City ID": city_id_list,
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}
cities_data = pd.DataFrame(cities_dict)
cities_data
# Out:
#      City ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          1  Puerto Ayora          74      EC  1596176957        93  -0.74
# 1          2    Bredasdorp           0      ZA  1596176957        93 -34.53
# 2          3       Te Anau          99      NZ  1596176957        90 -45.42
# 3          4        Alugan         100      PH  1596176958        88  12.22
# 4          5       Qaanaaq           0      GL  1596176958        85  77.48
# ..       ...           ...         ...     ...         ...       ...    ...
# 567      568     Chegdomyn          61      RU  1596176784        62  51.12
# 568      569       Tak Bai          20      TH  1596176785        66   6.26
# 569      570    Vila Velha          90      BR  1596176785        88 -20.33
# 570      571       Northam           0      GB  1596176785        66  51.03
# 571      572      Kirakira         100      SB  1596176786        79 -10.45
#
#         Lng  Max Temp  Wind Speed
# 0    -90.35     66.99        1.01
# 1     20.04     42.80        4.54
# 2    167.72     48.47        0.11
# 3    125.48     79.34       11.34
# 4    -69.36     34.57        3.74
# ..      ...       ...         ...
# 567  133.02     80.60        9.37
# 568  102.05     89.60        5.82
# 569  -40.29     73.99        9.17
# 570   -4.22     69.01        8.99
# 571  161.92     81.54        2.55
#
# [572 rows x 10 columns]

# %%
cities_data.to_csv("../output_data/cities_data.csv", encoding="utf-8", index=False)
cities_data.head()
# Out:
#    City ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        1  Puerto Ayora          74      EC  1596176957        93  -0.74
# 1        2    Bredasdorp           0      ZA  1596176957        93 -34.53
# 2        3       Te Anau          99      NZ  1596176957        90 -45.42
# 3        4        Alugan         100      PH  1596176958        88  12.22
# 4        5       Qaanaaq           0      GL  1596176958        85  77.48
#
#       Lng  Max Temp  Wind Speed
# 0  -90.35     66.99        1.01
# 1   20.04     42.80        4.54
# 2  167.72     48.47        0.11
# 3  125.48     79.34       11.34
# 4  -69.36     34.57        3.74

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# no cities with temperature above 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lat, max_temp, marker="o", facecolors="c", edgecolors="black")
plt.grid()
plt.title("City Latitude vs. Max Temperature (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, marker="o", facecolors="c", edgecolors="black")
plt.grid()
plt.title("City Latitude vs. Humidity (04/01/20)")
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloudiness, marker="o", facecolors="c", edgecolors="black")
plt.grid()
plt.title("City Latitude vs. Cloudiness (04/01/20)")
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind_speed, marker="o", facecolors="c", edgecolors="black")
plt.grid()
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
"Max Temp"
"Latitude"
# Out:
# The r-squared is: 0.8271188905041935

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
"Max Temp"
"Latitude"
# Out:
# The r-squared is: 0.39936284758885965

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
"Humidity"
"Latitude"
# Out:
# The r-squared is: 0.10829462153873139

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
"Humidity"
"Latitude"
# Out:
# The r-squared is: 0.0008996079328825663

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
"Cloudiness"
"Latitude"
# Out:
# The r-squared is: 0.05768812657005063

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
"Cloudiness"
"Latitude"
# Out:
# The r-squared is: 0.0684912094859049

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
"Wind Speed"
"Latitude"
# Out:
# The r-squared is: 0.023371104533850804

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
"Wind Speed"
"Latitude"
# Out:
# The r-squared is: 0.03381889207758188
